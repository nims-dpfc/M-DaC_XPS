# %% [markdown]
# # Usage of XRD tools for Jupyter Notebook

# %%
# %run -i ras2csv.py --encoding sjis ../source/XRD_RIGAKU.ras

# %%
# %run -i csv2graph.py XRD_RIGAKU.csv --jupytermode

# %%
# %run -i ras2raw_XRD.py ../source/XRD_RIGAKU.ras --encoding sjis xrd_raw_template.xml raw.xml --stdout
# Out:
# <?xml version="1.0" ?>
# <metadata>
# 	<meta key="DISP_LINE_COLOR" type="String">4294901760</meta>
# 	<meta key="FILE_COMMENT" type="String"></meta>
# 	<meta key="FILE_MD5" type="String"></meta>
# 	<meta key="FILE_MEMO" type="String"></meta>
# 	<meta key="FILE_OPERATOR" type="String">English</meta>
# 	<meta key="FILE_PACKAGE_NAME" type="String"></meta>
# 	<meta key="FILE_PART_ID" type="String">GeneralMeasurement(BB)</meta>
# 	<meta key="FILE_SAMPLE" type="String"></meta>
# 	<meta key="FILE_TYPE" type="String">RAS_RAW</meta>
# 	<meta key="FILE_USERGROUP" type="String">Academic</meta>
# 	<meta key="FILE_VERSION" type="String">1</meta>
# 	<meta key="HW_ATTACHMENT_ID" type="String">ATT0033</meta>
# 	<meta key="HW_ATTACHMENT_NAME" type="String">ASC6_Reflection</meta>
# 	<meta key="HW_COUNTER_ID-0" type="String">CUT0041</meta>
# 	<meta key="HW_COUNTER_ID-2" type="String">CMC0020</meta>
# 	<meta key="HW_COUNTER_NAME-0" type="String">DteX250(H)</meta>
# 	<meta key="HW_COUNTER_NAME-2" type="String">None</meta>
# 	<meta key="HW_COUNTER_PIXEL_SIZE" type="String">0.075</meta>
# 	<meta key="HW_COUNTER_SELECT_NAME" type="String">DteX250(H)</meta>
# 	<meta key="HW_GONIOMETER_ID" type="String">GON0021</meta>
# 	<meta key="HW_GONIOMETER_NAME" type="String">Standard</meta>
# 	<meta key="HW_GONIOMETER_RADIUS-0" type="String">90.0</meta>
# 	<meta key="HW_GONIOMETER_RADIUS-1" type="String">114.0</meta>
# 	<meta key="HW_GONIOMETER_RADIUS-2" type="String">190.0</meta>
# 	<meta key="HW_GONIOMETER_RADIUS-3" type="String">300.0</meta>
# 	<meta key="HW_GONIOMETER_RADIUS-4" type="String">187.0</meta>
# 	<meta key="HW_GONIOMETER_RADIUS-5" type="String">300.0</meta>
# 	<meta key="HW_GONIOMETER_RADIUS-6" type="String">113.0</meta>
# 	<meta key="HW_GONIOMETER_RADIUS-7" type="String">331.0</meta>
# 	<meta key="HW_R_ATTENUATER_AUTOMODE" type="String">0</meta>
# 	<meta key="HW_SAMPLE_HOLDER_ID" type="String">SMP0023</meta>
# 	<meta key="HW_SAMPLE_HOLDER_NAME" type="String">Z</meta>
# 	<meta key="HW_XG_CURRENT_UNIT" type="String">mA</meta>
# 	<meta key="HW_XG_FOCUS" type="String">0.4mm x 8mm</meta>
# 	<meta key="HW_XG_FOCUS_TYPE" type="String">Fine</meta>
# 	<meta key="HW_XG_TARGET_ATOMIC_NUMBER" type="String">29</meta>
# 	<meta key="HW_XG_TARGET_NAME" type="String">Cu</meta>
# 	<meta key="HW_XG_TYPE" type="String">Hermetic</meta>
# 	<meta key="HW_XG_VOLTAGE_UNIT" type="String">kV</meta>
# 	<meta key="HW_XG_WAVE_LENGTH_ALPHA1" type="String">1.540593</meta>
# 	<meta key="HW_XG_WAVE_LENGTH_ALPHA2" type="String">1.544414</meta>
# 	<meta key="HW_XG_WAVE_LENGTH_BETA" type="String">1.392246</meta>
# 	<meta key="HW_XG_WAVE_LENGTH_UNIT" type="String">Angstrom</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-0" type="String">ThetaS</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-1" type="String">ThetaD</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-2" type="String">TwoTheta</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-3" type="String">Omega</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-4" type="String">TwoThetaTheta</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-5" type="String">TwoThetaOmega</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-6" type="String">OmegaTwoTheta</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-7" type="String">Ts</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-8" type="String">PrimaryGeometry</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-9" type="String">PrimaryMirrorType</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-10" type="String">CBO-M</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-11" type="String">CBO</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-12" type="String">IncidentSollerSlit</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-13" type="String">IncidentSlitBox</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-14" type="String">IncidentSlitBox-_Axis</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-15" type="String">SlitDS</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-16" type="String">Zs</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-17" type="String">IncidentAxdSlit</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-18" type="String">LLS</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-19" type="String">DHLSlit</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-20" type="String">Z</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-21" type="String">DirectBeamStop</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-22" type="String">KnifeEdge</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-23" type="String">Beta</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-24" type="String">Changer</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-25" type="String">ReceivingSlitBox1</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-26" type="String">ReceivingSlitBox1-_Axis</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-27" type="String">SlitSS</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-28" type="String">Zr</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-29" type="String">ReceivingAxdSlit</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-30" type="String">Filter</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-31" type="String">ReceivingSollerSlit</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-32" type="String">ReceivingSlitBox2</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-33" type="String">ReceivingSlitBox2-_Axis</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-34" type="String">SlitRS</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-35" type="String">Attenuator</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-36" type="String">PHA</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-85" type="String">IncidentPrimary</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-86" type="String">IncidentMonochromator</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-87" type="String">ReceivingOptics</meta>
# 	<meta key="MEAS_COND_AXIS_NAME-88" type="String">CounterMonochromatorKind</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-0" type="String">0.8349</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-1" type="String">0.2882</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-2" type="String">1.1231</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-3" type="String">0.8349</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-4" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-5" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-6" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-7" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-8" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-9" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-10" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-11" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-12" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-13" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-14" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-15" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-16" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-17" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-18" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-19" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-20" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-21" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-22" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-23" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-24" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-25" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-26" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-27" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-28" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-29" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-30" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-31" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-32" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-33" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-34" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-35" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-36" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-85" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-86" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-87" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_OFFSET-88" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-0" type="String">0.0000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-1" type="String">0.0000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-2" type="String">0.0000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-3" type="String">0.0000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-4" type="String">0.0000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-5" type="String">0.0000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-6" type="String">0.0000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-7" type="String">-0.8219375</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-8" type="String">Right</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-9" type="String">None</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-10" type="String">0</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-11" type="String">DB</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-12" type="String">Soller_slit_2.5deg</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-13" type="String">0.300deg</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-14" type="String">0.995000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-15" type="String">0.300deg</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-16" type="String">-1.3975000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-17" type="String">5mm</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-18" type="String">5mm</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-19" type="String">5mm</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-20" type="String">-0.19142</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-21" type="String">None</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-22" type="String">None</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-23" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-24" type="String">1</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-25" type="String">Open</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-26" type="String">20.000000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-27" type="String">Open</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-28" type="String">-0.0790625</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-29" type="String">None</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-30" type="String">None</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-31" type="String">Soller_slit_2.5deg</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-32" type="String">Open</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-33" type="String">0.000</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-34" type="String">Open</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-35" type="String">Open</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-36" type="String">44</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-85" type="String">Standard</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-86" type="String">IPS_adaptor</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-87" type="String">No_unit</meta>
# 	<meta key="MEAS_COND_AXIS_POSITION-88" type="String">None</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-0" type="String">deg</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-1" type="String">deg</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-2" type="String">deg</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-3" type="String">deg</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-4" type="String">deg</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-5" type="String">deg</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-6" type="String">deg</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-7" type="String">mm</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-8" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-9" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-10" type="String">pulse</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-11" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-12" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-13" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-14" type="String">mm</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-15" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-16" type="String">mm</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-17" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-18" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-19" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-20" type="String">mm</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-21" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-22" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-23" type="String">deg</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-24" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-25" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-26" type="String">mm</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-27" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-28" type="String">mm</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-29" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-30" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-31" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-32" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-33" type="String">mm</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-34" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-35" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-36" type="String">div</meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-85" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-86" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-87" type="String"></meta>
# 	<meta key="MEAS_COND_AXIS_UNIT-88" type="String"></meta>
# 	<meta key="MEAS_COND_OPT_ATTR" type="String">DB</meta>
# 	<meta key="MEAS_COND_OPT_NAME" type="String"></meta>
# 	<meta key="MEAS_COND_XG_CURRENT" type="String">30</meta>
# 	<meta key="MEAS_COND_XG_VOLTAGE" type="String">40</meta>
# 	<meta key="MEAS_COND_XG_WAVE_TYPE" type="String">Ka</meta>
# 	<meta key="MEAS_DATA_COUNT" type="String">3501</meta>
# 	<meta key="MEAS_SCAN_AXIS_X" type="String">TwoThetaTheta</meta>
# 	<meta key="MEAS_SCAN_END_TIME" type="String">11/21/2017 08:37:42</meta>
# 	<meta key="MEAS_SCAN_MODE" type="String">CONTINUOUS</meta>
# 	<meta key="MEAS_SCAN_RESOLUTION_X" type="String">0.0002</meta>
# 	<meta key="MEAS_SCAN_SPEED" type="String">8.0000</meta>
# 	<meta key="MEAS_SCAN_SPEED_UNIT" type="String">deg/min</meta>
# 	<meta key="MEAS_SCAN_START" type="String">25.0000</meta>
# 	<meta key="MEAS_SCAN_START_TIME" type="String">11/21/2017 08:32:31</meta>
# 	<meta key="MEAS_SCAN_STEP" type="String">0.0100</meta>
# 	<meta key="MEAS_SCAN_STOP" type="String">60.0000</meta>
# 	<meta key="MEAS_SCAN_UNIT_X" type="String">deg</meta>
# 	<meta key="MEAS_SCAN_UNIT_Y" type="String">counts</meta>
# 	<column_num>1</column_num>
# 	<column_name>condition</column_name>
# </metadata>

# %%
# %run -i raw2primary_XRD.py raw.xml xrd_primary_template.xml primary.xml --stdout
# Out:
# <?xml version="1.0" ?>
# <metadata>
# 	<meta key="Operator_identifier" type="String">English</meta>
# 	<meta key="Year" type="Numeric">2017</meta>
# 	<meta key="Month" type="Numeric">11</meta>
# 	<meta key="Day" type="Numeric">21</meta>
# 	<meta key="Comment" type="String"></meta>
# 	<meta key="Memo" type="String"></meta>
# 	<meta key="Operator" type="String">English</meta>
# 	<meta key="Specimen" type="String"></meta>
# 	<meta key="Detector_Pixel_Size" type="Quantity" unit="mm">0.075</meta>
# 	<meta key="Selected_Detector_Name" type="String">DteX250(H)</meta>
# 	<meta key="X-ray_Target_Material" type="String">Cu</meta>
# 	<meta key="K_alpha_1_Wavelength" type="Quantity" unit="Angstrom">1.540593</meta>
# 	<meta key="K_alpha_2_Wavelength" type="Quantity" unit="Angstrom">1.544414</meta>
# 	<meta key="K_beta_Wavelength" type="Quantity" unit="Angstrom">1.392246</meta>
# 	<meta key="Optics_Attribute" type="String">DB</meta>
# 	<meta key="X-ray_Tube_Current" type="Quantity" unit="mA">30</meta>
# 	<meta key="X-ray_Tube_Voltage" type="Quantity" unit="kV">40</meta>
# 	<meta key="Wavelength_Type" type="String">K_alpha</meta>
# 	<meta key="Data_Point_Number" type="Numeric">3501</meta>
# 	<meta key="Scan_Axis" type="String">2Theta-Theta</meta>
# 	<meta key="Scan_Starting_Date_Time" type="String">11/21/2017 08:32:31</meta>
# 	<meta key="Scan_Ending_Date_Time" type="String">11/21/2017 08:37:42</meta>
# 	<meta key="Scan_Mode" type="String">CONTINUOUS</meta>
# 	<meta key="Scan_Speed" type="Quantity" unit="deg/min">8.0000</meta>
# 	<meta key="Scan_Step_Size" type="Quantity" unit="deg">0.0100</meta>
# 	<meta key="Scan_Starting_Position" type="Quantity" unit="deg">25.0000</meta>
# 	<meta key="Scan_Ending_Position" type="Quantity" unit="deg">60.0000</meta>
# 	<meta key="Scan_Axis_Unit" type="String">deg</meta>
# 	<meta key="Intensity_Unit" type="String">counts</meta>
# 	<column_num>1</column_num>
# 	<column_name>condition</column_name>
# </metadata>

# %% [markdown]
# # バッチ処理
#
# 上記のコマンドを一括して実行します。グラフと主要パラメータを表示します。

# %%
# %run -i batch_exe_XRD.py ../source/XRD_RIGAKU.ras --jupytermode
# Out:
# <?xml version="1.0" ?>
# <metadata>
# 	<meta key="Operator_identifier" type="String">English</meta>
# 	<meta key="Year" type="Numeric">2017</meta>
# 	<meta key="Month" type="Numeric">11</meta>
# 	<meta key="Day" type="Numeric">21</meta>
# 	<meta key="Comment" type="String"></meta>
# 	<meta key="Memo" type="String"></meta>
# 	<meta key="Operator" type="String">English</meta>
# 	<meta key="Specimen" type="String"></meta>
# 	<meta key="Detector_Pixel_Size" type="Quantity" unit="mm">0.075</meta>
# 	<meta key="Selected_Detector_Name" type="String">DteX250(H)</meta>
# 	<meta key="X-ray_Target_Material" type="String">Cu</meta>
# 	<meta key="K_alpha_1_Wavelength" type="Quantity" unit="Angstrom">1.540593</meta>
# 	<meta key="K_alpha_2_Wavelength" type="Quantity" unit="Angstrom">1.544414</meta>
# 	<meta key="K_beta_Wavelength" type="Quantity" unit="Angstrom">1.392246</meta>
# 	<meta key="Optics_Attribute" type="String">DB</meta>
# 	<meta key="X-ray_Tube_Current" type="Quantity" unit="mA">30</meta>
# 	<meta key="X-ray_Tube_Voltage" type="Quantity" unit="kV">40</meta>
# 	<meta key="Wavelength_Type" type="String">K_alpha</meta>
# 	<meta key="Data_Point_Number" type="Numeric">3501</meta>
# 	<meta key="Scan_Axis" type="String">2Theta-Theta</meta>
# 	<meta key="Scan_Starting_Date_Time" type="String">11/21/2017 08:32:31</meta>
# 	<meta key="Scan_Ending_Date_Time" type="String">11/21/2017 08:37:42</meta>
# 	<meta key="Scan_Mode" type="String">CONTINUOUS</meta>
# 	<meta key="Scan_Speed" type="Quantity" unit="deg/min">8.0000</meta>
# 	<meta key="Scan_Step_Size" type="Quantity" unit="deg">0.0100</meta>
# 	<meta key="Scan_Starting_Position" type="Quantity" unit="deg">25.0000</meta>
# 	<meta key="Scan_Ending_Position" type="Quantity" unit="deg">60.0000</meta>
# 	<meta key="Scan_Axis_Unit" type="String">deg</meta>
# 	<meta key="Intensity_Unit" type="String">counts</meta>
# 	<column_num>1</column_num>
# 	<column_name>condition</column_name>
# </metadata>
